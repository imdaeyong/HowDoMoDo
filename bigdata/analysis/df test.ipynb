# %%
import pandas as pd

# %%
df = pd.read_csv('2019-09-UTF.csv')
df
# Out:
# C:\Users\multicampus\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (8) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#          회원_시도명 회원_시군구명 개인기업구분    성별     연령   매출년월일  승인시간대1 가맹점_시도명 가맹점_시군구명  \
# 0            서울     NaN     개인  1.남성  4.40대  190921      13      강원      강릉시
# 1            강원     강릉시     기업  3.기업   0.기타  190904      12      강원      강릉시
# 2            강원     강릉시     기업  3.기업   0.기타  190925      12      강원      강릉시
# 3            강원     강릉시     기업  3.기업   0.기타  190916      12      강원      강릉시
# 4            강원     강릉시     개인  1.남성  4.40대  190926       6      강원      강릉시
# ...         ...     ...    ...   ...    ...     ...     ...     ...      ...
# 16138855     충북     충주시     개인  1.남성  3.30대  190912      20      충북      충주시
# 16138856     충북     충주시     개인  1.남성  4.40대  190906       7      충북      충주시
# ...

# %%
seoul = df[df['가맹점_시도명'] == '서울']

# %%
seoul[seoul['가맹점_읍면동명'] == '쌍문동']
# Out:
#         회원_시도명 회원_시군구명 개인기업구분    성별     연령   매출년월일  승인시간대1 가맹점_시도명 가맹점_시군구명  \
# 9310844     서울     NaN     개인  2.여성  5.50대  190923      14      서울      도봉구
# 9310845     서울     NaN     개인  2.여성  5.50대  190923      19      서울      도봉구
# 9310846     서울     NaN     개인  2.여성  5.50대  190925      16      서울      도봉구
# 9310847     서울     NaN     개인  2.여성  5.50대  190925      15      서울      도봉구
# 9310848     서울     NaN     개인  2.여성  5.50대  190924      15      서울      도봉구
# ...        ...     ...    ...   ...    ...     ...     ...     ...      ...
# 9337637     서울     NaN     개인  2.여성  3.30대  190923       9      서울      도봉구
# 9337638     서울     NaN     개인  2.여성  3.30대  190923      11      서울      도봉구
# 9337639     서울     NaN     개인  2.여성  3.30대  190923      10      서울      도봉구
# 9337640     서울     NaN     개인  2.여성  3.30대  190923      12      서울      도봉구
# 9337641     서울     NaN     개인  2.여성  3.30대  190902      14      서울      도봉구
#
#         가맹점_읍면동명  가맹점업종코드     결제금액  결제건수  회원수
# ...

# %%
ls = seoul['가맹점_읍면동명'].values
ls
# Out:
# array(['개포동', '개포동', '개포동', ..., '중화동', '중화동', '중화동'], dtype=object)

# %%
start = ""
cnt = 0
newls = []
for a in ls:
    if a != start:
        cnt+=1
        start = a
        newls.append(start)
cnt
# Out:
# 506

# %%
newls
# Out:
# ['개포동',
#  '논현2동',
#  '논현동',
#  '대치1동',
#  '대치동',
#  '도곡1동',
#  '도곡2동',
#  '도곡동',
#  '삼성1동',
#  '삼성동',
#  '세곡동',
#  '수서동',
#  '신사동',
#  '압구정1동',
#  '압구정동',
#  '역삼1동',
#  '역삼2동',
#  '역삼동',
#  '일원동',
#  '자곡동',
#  '청담2동',
#  '청담동',
#  '포이동',
#  '강일동',
#  '고덕동',
#  '길동',
#  '둔촌동',
#  '명일동',
#  '상일동',
#  '성내동',
#  '암사동',
#  '천호2동',
#  '천호동',
#  '미아1동',
#  '미아5동',
#  '미아동',
#  '번2동',
#  '번동',
#  '수유동',
#  '우이동',
#  '가양1동',
#  '가양2동',
#  '가양동',
#  '개화동',
#  '공항동',
#  '내발산2동',
#  '내발산동',
#  '등촌1동',
#  '등촌3동',
#  '등촌동',
#  '마곡동',
#  '방화1동',
#  '방화3동',
#  '방화동',
#  '염창동',
#  '오쇠동',
#  '외발산동',
#  '화곡6동',
#  '화곡7동',
#  '화곡동',
#  '남현동',
#  '봉천10동',
#  '봉천7동',
#  '봉천동',
#  '서림동',
#  '서원동',
#  '신림1동',
#  '신림4동',
#  '신림5동',
#  '신림9동',
#  '신림동',
#  '광장동',
#  '구의3동',
#  '구의동',
#  '군자동',
#  '노유1동',
#  '노유2동',
#  '노유동',
#  '능동',
#  '모진동',
#  '자양1동',
#  '자양3동',
#  '자양동',
#  '중곡동',
#  '화양동',
#  '가리봉동',
#  '개봉2동',
#  '개봉3동',
#  '개봉동',
#  '고척1동',
#  '고척동',
#  '구로1동',
#  '구로2동',
#  '구로3동',
#  '구로5동',
# ...
