# %%
from pandas import DataFrame
import pandas as pd

# %%
df = pd.read_csv('C:/ssafy/2nd/s03p23a305/bigdata/analysis/commercial district.csv', sep='|')
df
# Out:
#           상가업소번호       상호명   지점명 상권업종대분류코드  ...  층정보   호정보          경도         위도
# 0       19964615     석봉토스트   NaN         Q  ...    1   NaN  127.088387  37.549245
# 1       19977290      피자마루   약수점         Q  ...    1   NaN  127.010861  37.552153
# 2       19979960      홍능갈비   NaN         Q  ...    1   NaN  126.836078  37.538927
# 3       19983535       초밥왕   NaN         Q  ...    1   NaN  127.102490  37.515149
# 4       19969945      에브리돈  북가좌점         Q  ...    1   NaN  126.910288  37.579029
# ...          ...       ...   ...       ...  ...  ...   ...         ...        ...
# 370316  16458448      행운수산   NaN         Q  ...  NaN   110  126.916677  37.574907
# 370317  16475509  T.O.Ppc방   NaN         N  ...    1  B101  126.886101  37.526156
# 370318  16468028       철민사   NaN         D  ...    2   151  127.004702  37.569357
# 370319  16458247      창업마켓   NaN         F  ...  NaN   201  127.017681  37.511933
# ...

# %%
df.to_excel('output.xlsx')
