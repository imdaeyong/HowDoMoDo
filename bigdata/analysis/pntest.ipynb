# %%
pip install lxml
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup

# 네이버 영화 리뷰 - 트롤
url = "https://movie.naver.com/movie/bi/mi/point.nhn?code=183866#tab"

# html 소스 가져오기
res = requests.get(url)

# html 파싱
soup = BeautifulSoup(res.text, 'lxml')

soup
# Out:
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="no" http-equiv="imagetoolbar"/>
# <title>담보 : 네이버 영화</title>
# <meta content="https://ssl.pstatic.net/imgmovie/today/naverme/naverme_profile.jpg" property="me2:image"/>
# <meta content="네이버영화 담보" property="me2:post_tag"/>
# <meta content="네이버영화" property="me2:category1"/>
# <meta content="담보" property="me2:category2"/>
# <meta content="담보" property="og:title"/>
# <meta content="article" property="og:type"/>
# <meta content="https://movie.naver.com/movie/bi/mi/point.nhn?code=183866" property="og:url"/>
# <meta content="https://movie-phinf.pstatic.net/20200929_240/1601370752754trKxu_JPEG/movie_image.jpg?type=m665_443_2" property="og:image"/>
# <meta content="1993년 인천거칠고 까칠한 사채업자 두석(성동일)과 종배(김희원)는떼인 돈 받으러 갔다가 얼떨결에 9살..." property="og:description"/>
# ...

# %%
# 리뷰 리스트
ul = soup.find('ul', class_="rvw_list_area")
lis = ul.find_all('li')

# 리뷰 제목 출력
for li in lis:
    print(li.a.text)
# Out:
# 2020/10/02 - '담보', 현실성 없는 현실 비판, 고질적인 눈물 페티시, 묻혀버린 '아버지께 드리는 헌정'
# 코미디물이 아닌 "담보 (Pawn)"
# 시간이 쌓여 되는 가족도 있어, 영화 "담보"를 보고
# [예매권]<담보> 변함없는 JK 리스펙!!!
# 담보 _ 다음에 시간이 지나고 쌓이면 보물이 되는 것
# 20200929 : 영화 담보
# [담보] 아역배우가 다 살린, 영화 " 담보 " (+스포주의)
# 담보 - 1차 예고편
# 각박한 현실에 힐링 선사할 영화
# 하지원 주연 담보 영화전단지 까보기

# %%
import urllib
import urllib.request
import urllib.parse
import bs4
import re
import os
import time

# %%
def fText(s):
    if len(s): return innerHTML(s[0]).strip()
    return ''

# %%
import requests
from bs4 import BeautifulSoup
 
data = []
star_point = ""
title = ""
star_point_L = ""
star_point_S = ""
content = ""
True_False = False
star_point_F = []
title_f = []
content_f = []
# url='https://movie.naver.com/movie/point/af/list.nhn' 
url='https://movie.naver.com/movie/bi/mi/point.nhn?code=183866#tab' 

hdr = {'Accept-Language': 'ko_KR,en;q=0.8', 'User-Agent': ('Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.116 Safari/537.36')}
req = requests.get(url, headers=hdr)
html = req.text
soup = BeautifulSoup(html, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="no" http-equiv="imagetoolbar"/>
# <title>담보 : 네이버 영화</title>
# <meta content="https://ssl.pstatic.net/imgmovie/today/naverme/naverme_profile.jpg" property="me2:image">
# <meta content="네이버영화 담보" property="me2:post_tag">
# <meta content="네이버영화" property="me2:category1">
# <meta content="담보" property="me2:category2"/>
# <meta content="담보" property="og:title"/>
# <meta content="article" property="og:type"/>
# <meta content="https://movie.naver.com/movie/bi/mi/point.nhn?code=183866" property="og:url"/>
# <meta content="https://movie-phinf.pstatic.net/20200929_240/1601370752754trKxu_JPEG/movie_image.jpg?type=m665_443_2" property="og:image"/>
# <meta content="1993년 인천거칠고 까칠한 사채업자 두석(성동일)과 종배(김희원)는떼인 돈 받으러 갔다가 얼떨결에 9살..." property="og:description"/>
# ...

# %%
soup.find_all('p')
# Out:
# [<p class="info_spec">
#  <span>
#  <a href="/movie/sdb/browsing/bmovie.nhn?genre=1">드라마</a>
#  </span>
#  <span>
#  <a href="/movie/sdb/browsing/bmovie.nhn?nation=KR">한국</a>
#  </span>
#  <span>113분 </span>
#  <span>
#  <a href="/movie/sdb/browsing/bmovie.nhn?open=2020">2020</a>
#  <a href="/movie/sdb/browsing/bmovie.nhn?open=20200929">.09.29</a> 개봉
#
#
#
#  				</span>
#  <span>
#  					[국내]
#
#  							<a href="/movie/sdb/browsing/bmovie.nhn?grade=1001002">12세 관람가</a>
#  </span>
#  <span><a href="/movie/running/current.nhn?view=list&amp;tab=normal&amp;order=reserve">예매율 1위</a></span>
#  <span class="uio_ntz_btn">
#  <span class="ntz">누적관객<a class="help" href="#" id="boxofficeHelpButtonWide" title="누적관객 도움말 보기">누적관객 도움말</a></span>
#  <span class="ly_ntz" id="boxofficeHelpLayerWide" style="display:none;">
#  <span></span>
#  <strong class="blind">네티즌 평점 도움말</strong>
#  						영화진흥위원회 영화관 입장권 통합전산망 제공
# ...

# %%
cont = fText(soup.select('.score_reple p'))
cont = re.sub('<span [^>]+>.+?</span>', '', cont)
cont
# Out:
# ''

# %%
    
for a in range(0,10):
    data[a] = data[a].replace("\t","")
    data[a] = data[a].replace("\n","")
    star_point = data[a]
    star_point = star_point.replace("신고","")
    star_point = star_point.split("별점 - 총",1)
    title = str(star_point[0])
    star_point_L = star_point[1]
    
    star_point_S = star_point_L[:8]
    if(star_point_S[-1] != "0"):
        star_point_S = star_point_S[:-1]
        content = star_point_L[7:]
    else:
        content = star_point_L[8:]
    star_point_S = star_point_S.replace("10점 중","")
    content_f.append(content)
    star_point_F.append(star_point_S)
    title_f.append(title)
print("=======================================================================================================")
print("   ||                                 영화 평 정리                                               ||    ")
print("=======================================================================================================")
for b in range(0,10):
    print("영화 제목 : " + title_f[b] + "\n감상 : " + content_f[b] + "\n별점 : " + star_point_F[b])
    print("---------------------------------------------------------------------------------------------------")

# %%
//*[@id="_filtered_ment_0"]

# %%
test_url = "https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=183866&type=after&page=1"
resp = requests.get(test_url)
html = BeautifulSoup(resp.content, 'html.parser')
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>네이버 영화</title>
# <link href="https://ssl.pstatic.net/static/m/movie/icons/naver_movie_favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/css/common.css?20200806170632" rel="stylesheet" type="text/css">
# <link href="/css/movie_tablet.css?20200806170632" rel="stylesheet" type="text/css"/>
# <link href="/css/movie_end.css?20200806170632" rel="stylesheet" type="text/css"/>
# <script src="/js/deploy/movie.all.js?20200806170632" type="text/javascript"></script>
# </link></head>
# <body>
# <!-- content -->
# <input id="movieCode" name="movieCode" type="hidden" value="183866"/>
# <input id="onlyActualPointYn" name="onlyActualPointYn" type="hidden" value="N"/>
# <input id="includeSpoilerYn" name="includeSpoilerYn" type="hidden" value="N"/>
# <input id="order" name="order" type="hidden" value="sympathyScore"/>
# ...

# %%
score_result = html.find('div', {'class': 'score_result'})
lis = score_result.findAll('li')
# Out:
# <li>
# <div class="star_score">
# <span class="st_off"><span class="st_on" style="width:100.0%"></span></span><em>10</em>
# </div>
# <div class="score_reple">
# <p>
# <span class="ico_viewer">관람객</span>
# <!-- 스포일러 컨텐츠로 처리되는지 여부 -->
# <span id="_filtered_ment_0">
#
#
#
# 																소이가 보물입니다... 엄청 울고 나왔어요 ㅠㅠ
#
#
#
# 													</span>
# </p>
# <dl>
# <dt>
# <em>
# <a href="#" onclick="javascript:showPointListByNid(17165808, 'after');parent.clickcr(this, 'ara.uid', '', '', event); return false;" target="_top">
# <span>박슬기(past****)</span>
# </a>
# </em>
# <em>2020.09.29 15:56</em>
# </dt>
# <dd>
# <a class="go_report2" href="#" onclick="parent.clickcr(this, 'ara.report', '', '', event); common.report('false','past****', '81O4QQYscJvwXVXvNSreQtB/zOVpDbKrh7FZVp0jPRY=', '소이가 보물입니다... 엄청 울고 나왔어요 ㅠㅠ ', '17165808', 'point_after', false);return false;"><em>신고</em></a>
# </dd>
# </dl>
# </div>
# <div class="btn_area">
# ...

# %%
# Out:
# 0
# 소이가 보물입니다... 엄청 울고 나왔어요 ㅠㅠ
# 1
# 어린 승이 연기한 배우 너무 귀엽더라 ㅎㅎ 가족들과 보기에 딱 좋은 힐링무비~~
# 2
# 코로나 시대에 힐링이 필요했다,,, 사랑과 책임감으로 연결되는 세 사람. 추석에 힐링, 감동! 가족들이랑 함께하세유,,, ㅜ 담보맛! 아는 맛이지만 눈물 웃음!
# 3
# 담보 역할 맡은 소이님과 성동일님 연기 너무 쎄게 하셔서들 혼자 가서 질질 짰네요ㅠㅠ,, 너무 감동적이예요
# 4
# 오랜만에 가족들 같이 보기 좋은 영화네요. 담보 너무 귀엽!!
# 5
# 간만에 재밋게 봣어요 억즙이라면 억즙일수도 있지만 9점 줘도 안아까워요.
# 6
# 가족끼리 보기 좋은 감동영화네요뭉클하고 자극적이지않아 만족했어용
# 7
# 전체적인 스토리가 감동적이고 배우들의 연기가  좋았습니다특히 아역배우 너무 귀엽고 예쁘네요
# 8
# 담보야 담보야 ㅇ으으으 담보아야~~~
# 9

# %%
def review_list(code):
    pagelist = [1,2]
    review_ls = []
    for page in pagelist:
        url = "https://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code=" + code + "&type=after&page="+ str(page)
        resp = requests.get(url)
        html = BeautifulSoup(resp.content, 'html.parser')

        score_result = html.find('div', {'class': 'score_result'})
        lis = score_result.findAll('li')

        
        for idx, li in enumerate(lis):
            review_text = li.find('p').getText()
            review_text = review_text.replace('\n', '')
            review_text = review_text.replace('\t', '')
            review_text = review_text.replace('\r', '')
            review_text = review_text.replace('관람객', '')
            if(review_text != ''):
                review_ls.append(review_text)
    return review_ls

# %%
ls = review_list("183866")

# %%
ls
# Out:
# ['소이가 보물입니다... 엄청 울고 나왔어요 ㅠㅠ ',
#  '어린 승이 연기한 배우 너무 귀엽더라 ㅎㅎ 가족들과 보기에 딱 좋은 힐링무비~~ ',
#  '코로나 시대에 힐링이 필요했다,,, 사랑과 책임감으로 연결되는 세 사람. 추석에 힐링, 감동! 가족들이랑 함께하세유,,, ㅜ 담보맛! 아는 맛이지만 눈물 웃음! ',
#  '담보 역할 맡은 소이님과 성동일님 연기 너무 쎄게 하셔서들 혼자 가서 질질 짰네요ㅠㅠ,, 너무 감동적이예요 ',
#  '오랜만에 가족들 같이 보기 좋은 영화네요. 담보 너무 귀엽!! ',
#  '간만에 재밋게 봣어요 억즙이라면 억즙일수도 있지만 9점 줘도 안아까워요. ',
#  '가족끼리 보기 좋은 감동영화네요뭉클하고 자극적이지않아 만족했어용 ',
#  '전체적인 스토리가 감동적이고 배우들의 연기가  좋았습니다특히 아역배우 너무 귀엽고 예쁘네요 ',
#  '담보야 담보야 ㅇ으으으 담보아야~~~ ',
#  '스토리가 연기력을 못 따라감 ',
#  '성동일의 연기가 참 대단했습니다 그리고 음.... ',
#  '스토리가 탄탄하지는 않은거 같아요 억지로 감동적인부분을 많이 끼어넣은느낌 그래도 저도 인간인지라 휴머니즘 불러일으키는 장면에서는 어쩔수 없이 눈물ㅠ ',
#  '꼭 낳았다고 가족인가요~ 함께 살면 가족이죠 ^^ ',
#  '오랜만에 따뜻한 힐링 영화 ',
#  '와 ..이런 영화 얼마만이냐.. ',
#  '펑펑 울다가 나왔어요. ㅠ 추석영화로 최고~ ',
#  '마지막 장면 너무 슬프고 인상적이었습니다아빠.. 그 한마디.. ',
#  '보고싶었던 영화인데 드디어 봤어요! 진짜 생각보다 더 좋고 마음에 드는 영화에요 ',
#  'ㅠㅠ 나진짜 엄청 울었다;; ']

# %%
len(ls)
# Out:
# 19
